# %% [markdown]
# # Project

# %%
import pandas as pd


# Load the dataset
df = pd.read_csv("C:\\Users\\alphi\\Downloads\\IMDB Dataset.csv\\IMDB Dataset.csv")

# Display basic info
print(df.info())
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   review      50000 non-null  object
#  1   sentiment   50000 non-null  int64
#  2   word_count  50000 non-null  int64
#  3   char_count  50000 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB
# None
#                                               review  sentiment  word_count  \
# 0  One of the other reviewers has mentioned that ...          1         307
# 1  A wonderful little production. <br /><br />The...          1         162
# 2  I thought this was a wonderful way to spend ti...          1         166
# 3  Basically there's a family where a little boy ...          0         138
# 4  Petter Mattei's "Love in the Time of Money" is...          1         230
#
#    char_count
# 0        1761
# 1         998
# 2         926
# 3         748
# 4        1317

# %% [markdown]
# # Handling Missing Values

# %%
print(df.isnull().sum())  # Check for missing values
df.dropna(inplace=True)  # Remove missing values (if any)
# Out:
# review        0
# sentiment     0
# word_count    0
# char_count    0
# dtype: int64

# %% [markdown]
# # Handling Duplicates
# ## Removing duplicate values if they exist

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# # Text Pre-processing
# ### Lowercasing: Convert text to lowercase.
# ### Removing Special Characters: Remove punctuation, symbols, and numbers.
# ### Removing Stopwords: Filter out words like "the," "is," "and" (using NLTK or SpaCy).
# ### Stemming/Lemmatization: Reduce words to their root form.
# ### Tokenization: Split text into words.

# %%
import re
import nltk
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer

# Download necessary NLTK resources (only once)
nltk.download('stopwords', quiet=True)
nltk.download('punkt', quiet=True)

# Load dataset

df = pd.read_csv("C:\\Users\\alphi\\Downloads\\IMDB Dataset.csv\\IMDB Dataset.csv")

# Ensure 'review' column exists
if "review" not in df.columns:
    raise ValueError("Column 'review' not found in the dataset.")

# Preprocessing setup
stop_words = set(stopwords.words("english"))
stemmer = PorterStemmer()

def preprocess_text(text):
    if pd.isna(text):  # Handle NaN values
        return ""
    
    text = text.lower()  # Convert to lowercase
    text = re.sub(r'\W', ' ', text)  # Remove special characters
    tokens = word_tokenize(text)  # Tokenization
    tokens = [word for word in tokens if word not in stop_words]  # Remove stopwords
    tokens = [stemmer.stem(word) for word in tokens]  # Stemming
    return " ".join(tokens)

# %% [markdown]
# # Convert Categorical Data

# %%
df["sentiment"] = df["sentiment"].map({"positive": 1, "negative": 0})

# %% [markdown]
# # Handle Class Imbalance

# %% [markdown]
# # Feature Engineering

# %%
df["word_count"] = df["review"].apply(lambda x: len(x.split()))
df["char_count"] = df["review"].apply(lambda x: len(x))

# %% [markdown]
# # Save the Cleaned Dataset

# %%
df.to_csv("C:\\Users\\alphi\\Downloads\\IMDB Dataset.csv\\IMDB Dataset.csv", index=False)
cleaned_df = df.copy()

# %%
cleaned_df.head(20)
# Out:
#                                                review  sentiment  word_count  \
# 0   One of the other reviewers has mentioned that ...        NaN         307
# 1   A wonderful little production. <br /><br />The...        NaN         162
# 2   I thought this was a wonderful way to spend ti...        NaN         166
# 3   Basically there's a family where a little boy ...        NaN         138
# 4   Petter Mattei's "Love in the Time of Money" is...        NaN         230
# 5   Probably my all-time favorite movie, a story o...        NaN         119
# 6   I sure would like to see a resurrection of a u...        NaN         150
# 7   This show was an amazing, fresh & innovative i...        NaN         174
# 8   Encouraged by the positive comments about this...        NaN         130
# 9   If you like original gut wrenching laughter yo...        NaN          33
# 10  Phil the Alien is one of those quirky films wh...        NaN          96
# 11  I saw this movie when I was about 12 when it c...        NaN         180
# 12  So im not a big fan of Boll's work but then ag...        NaN         398
# 13  The cast played Shakespeare.<br /><br />Shakes...        NaN         117
# 14  This a fantastic movie of three prisoners who ...        NaN          50
# 15  Kind of drawn in by the erotic scenes, only to...        NaN         140
# 16  Some films just simply should not be remade. T...        NaN         146
# 17  This movie made it into one of my top 10 most ...        NaN         228
# 18  I remember this film,it was the first film i h...        NaN         129
# 19  An awful film! It must have been up against so...        NaN         133
#
#     char_count
# 0         1761
# 1          998
# 2          926
# 3          748
# 4         1317
# 5          656
# 6          726
# 7          934
# 8          681
# 9          176
# 10         578
# 11         937
# 12        2227
# 13         662
# 14         275
# 15         830
# 16         720
# 17        1322
# 18         639
# 19         741

# %%
df.head(20)
# Out:
#                                                review  sentiment  word_count  \
# 0   One of the other reviewers has mentioned that ...        NaN         307
# 1   A wonderful little production. <br /><br />The...        NaN         162
# 2   I thought this was a wonderful way to spend ti...        NaN         166
# 3   Basically there's a family where a little boy ...        NaN         138
# 4   Petter Mattei's "Love in the Time of Money" is...        NaN         230
# 5   Probably my all-time favorite movie, a story o...        NaN         119
# 6   I sure would like to see a resurrection of a u...        NaN         150
# 7   This show was an amazing, fresh & innovative i...        NaN         174
# 8   Encouraged by the positive comments about this...        NaN         130
# 9   If you like original gut wrenching laughter yo...        NaN          33
# 10  Phil the Alien is one of those quirky films wh...        NaN          96
# 11  I saw this movie when I was about 12 when it c...        NaN         180
# 12  So im not a big fan of Boll's work but then ag...        NaN         398
# 13  The cast played Shakespeare.<br /><br />Shakes...        NaN         117
# 14  This a fantastic movie of three prisoners who ...        NaN          50
# 15  Kind of drawn in by the erotic scenes, only to...        NaN         140
# 16  Some films just simply should not be remade. T...        NaN         146
# 17  This movie made it into one of my top 10 most ...        NaN         228
# 18  I remember this film,it was the first film i h...        NaN         129
# 19  An awful film! It must have been up against so...        NaN         133
#
#     char_count
# 0         1761
# 1          998
# 2          926
# 3          748
# 4         1317
# 5          656
# 6          726
# 7          934
# 8          681
# 9          176
# 10         578
# 11         937
# 12        2227
# 13         662
# 14         275
# 15         830
# 16         720
# 17        1322
# 18         639
# 19         741

# %% [markdown]
# ### count vectorization

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
